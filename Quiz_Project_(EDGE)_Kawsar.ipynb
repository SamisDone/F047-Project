# %%
import pandas as pd
data = pd.read_excel("/content/basic_python_mcq_questions.xlsx")

# %%
data
# Out:
#                                         question_text option_a option_b  \
# 0   What is the correct file extension for Python ...      .py  .python
# 1    Which keyword is used to print output in Python?     echo    print
# 2        Which symbol is used for comments in Python?       //       /*
# 3       What is the output type of input() in Python?      int    float
# 4     Which data type is used to store whole numbers?      int      str
# 5      Which operator is used for addition in Python?        +        -
# 6       What is the correct way to create a variable?    5 = x   x == 5
# 7   Which function is used to get the length of a ...   size()  count()
# 8            Which of the following is a Python list?  {1,2,3}  (1,2,3)
# 9         Which keyword is used for a loop in Python?   repeat     loop
# 10                       What is the result of 5 > 3?    False     True
# 11    Which function converts a string to an integer?    str()  float()
# ...

# %%
score = 0
total_questions = len(data)

# %%
for index, row in data.iterrows():
    print("-------------------------------")
    print("Question No: ", index + 1)
    print(row["question_text"])
    print("A: ", row["option_a"])
    print("B: ", row["option_b"])
    print("C: ", row["option_c"])
    print("D: ", row["option_d"])
    print("-------------------------------")

    user_answer = input("Choose correct option (A/B/C/D): ").upper()

    if user_answer == row["correct_answer"]:
        print("✅ Correct Answer")
        score += 1
    else:
        print("❌ Wrong Answer")
    print("Explanation: ", row["answer_explanation"])

print("Quiz Completed!")
print("Your Score: ", score, "/", total_questions)
# Out:
# -------------------------------
# Question No:  1
# What is the correct file extension for Python files?
# Option A:  .py
# Option B:  .python
# Option C:  .pt
# Option D:  .p
# -------------------------------
# Choose correct option (A/B/C/D): A
# ✅ Correct Answer
# Explanation:  Python files use the .py extension.
# -------------------------------
# Question No:  2
# Which keyword is used to print output in Python?
# Option A:  echo
# Option B:  print
# Option C:  show
# Option D:  write
# -------------------------------
# Choose correct option (A/B/C/D): B
# ✅ Correct Answer
# Explanation:  The print() function is used to display output in Python.
# -------------------------------
# Question No:  3
# Which symbol is used for comments in Python?
# Option A:  //
# Option B:  /*
# Option C:  #
# Option D:  --
# -------------------------------
# Choose correct option (A/B/C/D): C
# ✅ Correct Answer
# Explanation:  The # symbol is used for single-line comments in Python.
# ...
